-- %%
select * from ecommerce_dev.audit.pipeline_run_log

-- %%
select * from ecommerce_dev.audit.rejected_records

-- %%
select * from ecommerce_dev.audit.schema_validation_log

-- %%
select * from ecommerce_dev.metadata.data_quality_rules

-- %%
select * from ecommerce_dev.metadata.ingestion_config

-- %%
select * from ecommerce_dev.metadata.processed_files

-- %%
select * from ecommerce_dev.metadata.required_schema
