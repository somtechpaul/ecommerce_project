# %%
# ==========================================================
# Bronze Ingestion Notebook
# ==========================================================

# dbutils.library.restartPython()

from pei_pipeline.main import main

result = main(
    spark=spark,
    dbutils=dbutils,
    stage="ingestion"
)

print(result)
