# %%
# ==========================================================
# Schema Validation Notebook
# ==========================================================

from pei_pipeline.main import main

result = main(
    spark=spark,
    dbutils=dbutils,
    stage="schema_validation"
)

display(result)

# %%
# This pipeline transforms raw Bronze data into a trusted, typed, validated dataset by:

# Reading the required schema from metadata.
# Casting Bronze columns to the expected data types.
# Validating the resulting schema against the metadata definition.
# Logging any schema issues.
# Writing the validated data to the next layer (Validated/Silver) using the appropriate write strategy (overwrite or merge) defined in metadata.
# Recording detailed audit information for monitoring and troubleshooting.
